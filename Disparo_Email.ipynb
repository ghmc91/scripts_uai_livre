# %%
import pandas as pd
import smtplib, ssl
import smtplib
# import the corresponding modules
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import email.mime.application

# %%
df = pd.read_excel('C:/Users/Usuario/Documents/UaiLivre/arquivos/Sellers.xlsx')
df['Produção Mensal'] = df['Produção Mensal'].astype(int)
df = df.loc[df['Produção Mensal'] > 20]
df = df.dropna(subset=['Empresa', 'e-mail'])

# %%
sender_email = "uailivre@gmail.com"
pwd = "uatyuuipixorgfvy"

message = MIMEMultipart("alternative")
message["Subject"] = "Prazer, Uai Livre: o Market Place do artesão mineiro"
message["From"] = sender_email
filename = r"Apresentacao_Uai_Livre.pdf"
fp=open(filename,'rb')
att = email.mime.application.MIMEApplication(fp.read(),_subtype="pdf")
fp.close()
att.add_header('Content-Disposition','attachment',filename=filename)
message.attach(att)
instagram = 'https://instagram.com/uai.livre?igshid=YmMyMTA2M2Y='
smtp_server = "smtp.gmail.com"
message['Cc'] = 'gabriel'

# %%
df = df.iloc[10:]
df
# Out:
#     Categoria                                            Empresa  \
# 16   Minerais                             Joanina Neres de Souza
# 18   Minerais                         José Adolfo Viana de Souza
# 19   Minerais                            José Roberto dos Santos
# 22   Minerais                                      Magno Barrozo
# 23   Minerais                                      Mara Tameirão
# 24   Minerais                                    Márcio Ferreira
# 25   Minerais                      Maria Aparecida Alves Lacerda
# 26   Minerais                     Maria Aparecida Gomes de Sousa
# 27   Minerais                     Maria Claudia de Matos Miranda
# 28   Minerais                         Maria de Fátima Nascimento
# 29   Minerais                          Maria Helena Ribeiro Hugo
# 30   Minerais                  Maria Tereza Gomes Lima Fernandes
# 31   Minerais                                     Marli di Paula
# ...

# %%
for empresa, e_mail in zip(df['Empresa'].to_list(), df['e-mail'].to_list()):
    sender_email = "uailivre@gmail.com"
    pwd = "uatyuuipixorgfvy"
    message = MIMEMultipart("alternative")
    message["Subject"] = "Prazer, Uai Livre: o Market Place do artesão mineiro"
    message["From"] = sender_email
    filename = r"Apresentacao_Uai_Livre.pdf"
    fp=open(filename,'rb')
    att = email.mime.application.MIMEApplication(fp.read(),_subtype="pdf")
    fp.close()
    att.add_header('Content-Disposition','attachment',filename=filename)
    message.attach(att)
    instagram = 'https://instagram.com/uai.livre?igshid=YmMyMTA2M2Y='
    smtp_server = "smtp.gmail.com"
    message['Cc'] = 'gabriel.costa6@estudante.ufla.br'
    message["To"] = e_mail
    html = """\
            <html>
              <body>
                <p>Bom dia, {}<br>
                Já imaginou fazer parte de uma plataforma exclusiva para a comercialização de produtos artesanais mineiros? Venha conhecer a Uai Livre, o marketplace do artesão mineiro.
                De maneira bem simples, nossa plataforma funciona como um mercado livre exclusivo para artesanatos. Após a efetivação do cadastro como vendedor, basta anunciar seus produtos na plataforma e aguardar pelas vendas. 
                Ofertamos todos os meios necessários para garantir praticidade e segurança na venda, como cálculo automático de frete, reajuste de preço de acordo com a forma de pagamento e proteção contra fraudes. 
                Estamos enviando em anexo uma apresentação detalhada e com explicações sobre o funcionamento do nosso marketplace. 
                Seja um vendedor Uai Livre e ajude a expandir a secular arte mineira para novos mercados! <br>
                <br>Aguardamos seu retorno por e-mail ou pelo nosso instagram: {} <br>
                
                
                <br>Atenciosamente,
                <br> Gustavo Costa - CEO Uai Livre
                <br> 32 99118-7131
                </p>
              </body>
            </html>
            """.format(empresa, instagram)
    part2 = MIMEText(html, "html")
    message.attach(part2)
    context = ssl.create_default_context()
    with smtplib.SMTP(smtp_server, 587) as server:
        server.ehlo()  # Can be omitted
        server.starttls(context=context)
        server.ehlo()  # Can be omitted
        server.login(sender_email,pwd) #logging into out email id
        text = message.as_string()
        server.sendmail(sender_email,e_mail,text)
        print('E-mail enviado para {}'.format(empresa)) #priting a message on sending the mail
# Out:
# E-mail enviado para Associação de Artesãos de Minas Novas
# E-mail enviado para Atelier Daniele Drummond
# E-mail enviado para Atelier Iara Nicola
# E-mail enviado para Cerâmicas Flávia Rocha
# E-mail enviado para Cristiana de Souza e Silva
# E-mail enviado para Denise Mascarenhas
# E-mail enviado para Denise Reda Federico
# E-mail enviado para Dirléia Peixoto
# E-mail enviado para Eny Amorim
# E-mail enviado para Grazielle Miranda de Matos

# %%
sender_email = "uailivre@gmail.com"
pwd = "uatyuuipixorgfvy"
message = MIMEMultipart("alternative")
message["Subject"] = "Prazer, Uai Livre: o Market Place do artesão mineiro"
message["From"] = sender_email
message["To"] = receiver_email
filename = r"C:\Users\Usuario\Documents\UaiLivre\arquivos\UaiLivre_captação_sellers.pdf"
with open(filename, "rb") as attachment:
    # The content type "application/octet-stream" means that a MIME attachment is a binary file
    part = MIMEBase("application", "octet-stream")
    part.set_payload(attachment.read())


part2 = MIMEText(html, "html")

smtp_server=smtplib.SMTP("smtp.gmail.com",587)
smtp_server.ehlo() #setting the ESMTP protocol
smtp_server.starttls() #setting up to TLS connection
smtp_server.ehlo() #calling the ehlo() again as encryption happens on calling startttls()
smtp_server.login(sender_email,pwd) #logging into out email id
msg_to_be_sent ='''
Hello, receiver!
Hope you are doing well.
Welcome to PythonGeeks!
'''
#sending the mail by specifying the from and to address and the message 
smtp_server.sendmail(sender_email,receiver_email,msg_to_be_sent)
print('Successfully the mail is sent') #priting a message on sending the mail
# Out:
# Successfully the mail is sent

# %%
import smtplib

# import the corresponding modules
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

port = 2525 
smtp_server = "smtp.mailtrap.io"
login = "uailivre@gmail.com" # paste your login generated by Mailtrap
password = "UaiLibre22" # paste your password generated by Mailtrap

subject = "An example of boarding pass"
sender_email = "mailtrap@example.com"
receiver_email = "gustavo_martins1991@hotmail.com"

message = MIMEMultipart()
message["From"] = sender_email
message["To"] = receiver_email
message["Subject"] = subject

# Add body to email
body = "This is an example of how you can send a boarding pass in attachment with Python"
message.attach(MIMEText(body, "plain"))

filename = r"C:\Users\Usuario\Documents\UaiLivre\arquivos\UaiLivre_captação_sellers.pdf"
# Open PDF file in binary mode

# We assume that the file is in the directory where you run your Python script from
with open(filename, "rb") as attachment:
    # The content type "application/octet-stream" means that a MIME attachment is a binary file
    part = MIMEBase("application", "octet-stream")
    part.set_payload(attachment.read())

# Encode to base64
encoders.encode_base64(part)

# Add header 
part.add_header(
    "Content-Disposition",
    f"attachment; filename= {filename}",
)

# Add attachment to your message and convert it to string
message.attach(part)
text = message.as_string()

# send your email
with smtplib.SMTP("smtp.mailtrap.io", 2525) as server:
    server.login(login, password)
    server.sendmail(
        sender_email, receiver_email, text
    )
print('Sent')
# Out:
# ---------------------------------------------------------------------------
# SMTPServerDisconnected                    Traceback (most recent call last)
# Cell In [6], line 51
#      49 # send your email
#      50 with smtplib.SMTP("smtp.mailtrap.io", 2525) as server:
# ---> 51     server.login(login, password)
#      52     server.sendmail(
#      53         sender_email, receiver_email, text
#      54     )
#      55 print('Sent')
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
# ...

# %%
html = """\
<html>
  <body>
    <p>Hi,<br>
       How are you?<br>
       <a href="http://www.realpython.com">Real Python</a> 
       has many great tutorials.
    </p>
  </body>
</html>
"""
part2 = MIMEText(html, "html")
message.attach(part2)
context = ssl.create_default_context()
with smtplib.SMTP(smtp_server, 587) as server:
    server.ehlo()  # Can be omitted
    server.starttls(context=context)
    server.ehlo()  # Can be omitted
    server.login(sender_email, "UaiLibre22")
    server.sendmail(sender_email, receiver_email, message)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In [3], line 19
#      17 server.starttls(context=context)
#      18 server.ehlo()  # Can be omitted
# ---> 19 server.login(sender_email, "UaiLibre22")
#      20 server.sendmail(sender_email, receiver_email, message)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# ...

# %%
import win32com.client as win32
from datetime import datetime
import os

# %%
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.Subject = "Prazer, Uai Livre: o Market Place do artesão mineiro"
mail.To = "gustavo_martins1991@hotmail.com"
attachment = mail.Attachments.Add(r"C:\Users\Usuario\Documents\UaiLivre\arquivos\UaiLivre_captação_sellers.pdf")
attachment.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "currency_img")
mail.HTMLBody = r"""
Dear Carrie,<br><br>
The highlighted of currencies exchange prices is as follow:<br><br>
<img src="cid:currency_img"><br><br>
For more details, you can check the table in the Excel file attached.<br><br>
Best regards,<br>
Yeung
"""
mail.Attachments.Add(os.getcwd() + "\\Currencies.xlsx")
mail.Send()

# %%
df = pd.read_excel('C:/Users/Usuario/Documents/UaiLivre/arquivos/Sellers.xlsx')
df['Produção Mensal'] = df['Produção Mensal'].astype(int)
df = df.loc[df['Produção Mensal'] > 20]
df = df.dropna(subset=['Empresa', 'e-mail'])
df
# Out:
#     Categoria                                Empresa  \
# 2    Minerais  Associação de Artesãos de Minas Novas
# 3    Minerais               Atelier Daniele Drummond
# 4    Minerais                    Atelier Iara Nicola
# 7    Minerais                 Cerâmicas Flávia Rocha
# 8    Minerais             Cristiana de Souza e Silva
# ..        ...                                    ...
# 124    Têxtil                Mulheres Bordando Minas
# 128    Têxtil                              Panoletos
# 133    Têxtil                            Ria Bordone
# 135    Têxtil              Simara Marques Bernardes
# 138    Têxtil                             Vera Naves
#
#                                 e-mail                 instagram  \
# 2                 artesaomn1@gmail.com                       NaN
# 3           vendas@danieledrummond.com  @danieledrummond.atelier
# 4             iarascnicola@hotmail.com      @atelier_iara_nicola
# ...
